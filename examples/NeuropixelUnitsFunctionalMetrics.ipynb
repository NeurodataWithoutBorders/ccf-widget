# %%
import numpy as np
import pandas as pd

from ccfwidget import CCFWidget

# %%
# Neuropixel data from Brian Hu
# Re: https://www.biorxiv.org/content/10.1101/805010v1
# A survey of spiking activity reveals a functional hierarchy of mouse corticothalamic visual areas
# Joshua H. Siegle, et. al.
units_csv = 'selected_units.csv'
functional_metrics_csv = 'selected_unit_metrics.csv'

# %%
units_df = pd.read_csv(units_csv)
units_df = units_df.set_index('id').sort_index()
units_df
# Out:
#            waveform_PT_ratio  waveform_amplitude  amplitude_cutoff  \
# id
# 951851547           0.653767          297.607635          0.000621
# 951851557           0.386431          138.823815          0.049813
# 951851661           0.507749          129.147135          0.020340
# 951851709           0.588997          160.717245          0.028912
# 951851731           0.409587          178.858485          0.000445
# ...                      ...                 ...               ...
# 951879329           0.344197          133.912740          0.000755
# 951879341           0.519155          155.048010          0.000030
# 951879353           0.637814          198.288675          0.000009
# 951879365           0.865141           77.586795          0.003516
# 951879452           0.469393          126.817470          0.000612
#
#            cumulative_drift   d_prime  waveform_duration  ecephys_channel_id  \
# id
# 951851547            130.68  5.064922           0.192295           850170494
# 951851557            167.93  4.346613           0.247236           850170494
# 951851661            217.88  3.661428           0.219765           850170506
# 951851709            115.20  4.873299           0.302178           850170514
# 951851731            189.63  5.267328           0.288442           850170524
# ...                     ...       ...                ...                 ...
# 951879329            175.97  3.785565           0.673032           850163894
# 951879341            168.59  6.077892           0.604355           850163896
# 951879353             91.63       NaN           0.604355           850163898
# 951879365            276.80       NaN           0.714238           850163898
# 951879452            262.08  3.687309           0.755444           850164338
#
#            firing_rate  waveform_halfwidth  isi_violations  ...  phase  \
# id                                                          ...
# 951851547     7.494949            0.137353        0.057311  ...     3a
# 951851557    28.709384            0.151089        0.011534  ...     3a
# 951851661    30.434930            0.109883        0.023880  ...     3a
# 951851709    39.702313            0.192295        0.007617  ...     3a
# 951851731    47.135419            0.151089        0.016639  ...     3a
# ...                ...                 ...             ...  ...    ...
# 951879329     1.667407            0.192295        0.040878  ...     3a
# 951879341     3.328546            0.178559        0.013677  ...     3a
# 951879353     2.984190            0.164824        0.004254  ...     3a
# 951879365     4.468755            0.288442        0.081573  ...     3a
# 951879452     1.118073            0.206030        0.090914  ...     3a
#
#            sampling_rate  has_lfp_data   date_of_acquisition  \
# id
# 951851547   29999.966623          True  2018-10-26T19:58:51Z
# 951851557   29999.966623          True  2018-10-26T19:58:51Z
# 951851661   29999.966623          True  2018-10-26T19:58:51Z
# 951851709   29999.966623          True  2018-10-26T19:58:51Z
# 951851731   29999.966623          True  2018-10-26T19:58:51Z
# ...                  ...           ...                   ...
# 951879329   29999.993938          True  2018-10-26T19:58:51Z
# 951879341   29999.993938          True  2018-10-26T19:58:51Z
# 951879353   29999.993938          True  2018-10-26T19:58:51Z
# 951879365   29999.993938          True  2018-10-26T19:58:51Z
# 951879452   29999.993938          True  2018-10-26T19:58:51Z
#
#                    published_at  specimen_id           session_type  \
# id
# 951851547  2019-10-03T00:00:00Z    726162197  brain_observatory_1.1
# 951851557  2019-10-03T00:00:00Z    726162197  brain_observatory_1.1
# 951851661  2019-10-03T00:00:00Z    726162197  brain_observatory_1.1
# 951851709  2019-10-03T00:00:00Z    726162197  brain_observatory_1.1
# 951851731  2019-10-03T00:00:00Z    726162197  brain_observatory_1.1
# ...                         ...          ...                    ...
# 951879329  2019-10-03T00:00:00Z    726162197  brain_observatory_1.1
# 951879341  2019-10-03T00:00:00Z    726162197  brain_observatory_1.1
# 951879353  2019-10-03T00:00:00Z    726162197  brain_observatory_1.1
# 951879365  2019-10-03T00:00:00Z    726162197  brain_observatory_1.1
# 951879452  2019-10-03T00:00:00Z    726162197  brain_observatory_1.1
#
#            age_in_days  sex  genotype
# id
# 951851547         92.0    M     wt/wt
# 951851557         92.0    M     wt/wt
# 951851661         92.0    M     wt/wt
# 951851709         92.0    M     wt/wt
# 951851731         92.0    M     wt/wt
# ...                ...  ...       ...
# 951879329         92.0    M     wt/wt
# 951879341         92.0    M     wt/wt
# 951879353         92.0    M     wt/wt
# 951879365         92.0    M     wt/wt
# 951879452         92.0    M     wt/wt
#
# [511 rows x 45 columns]

# %%
structures = list(units_df.ecephys_structure_acronym.unique())
structures.sort()
structures
# Out:
# ['LGd', 'LP', 'VISal', 'VISam', 'VISl', 'VISp', 'VISpm', 'VISrl']

# %%
functional_metrics_df = pd.read_csv(functional_metrics_csv)
functional_metrics_df = functional_metrics_df.set_index('ecephys_unit_id').sort_index()
functional_metrics_df
# Out:
#                  c50_dg  area_rf    fano_dg   fano_fl   fano_ns   fano_rf  \
# ecephys_unit_id
# 951851547           NaN   1100.0  10.765591  3.972316  4.943478  5.579487
# 951851557           NaN    400.0   0.820221  0.869048  1.075294  2.734658
# 951851661           NaN   1000.0  13.854313  4.911065  4.653991  4.953690
# 951851709           NaN   1100.0   2.983748  3.281159  1.033560  7.617391
# 951851731           NaN   1800.0   5.813139  0.230842  0.705381  1.421795
# ...                 ...      ...        ...       ...       ...       ...
# 951879329           NaN      0.0   5.996748  1.446667  3.977736  2.800000
# 951879341           NaN    300.0   9.820290  1.631111  3.580909  1.933333
# 951879353           NaN    100.0   2.631925  1.961026  2.714286  1.933333
# 951879365           NaN    200.0   5.608602  1.433615  1.626364  2.933333
# 951879452           NaN    100.0   3.266667  1.096667  1.705490  1.600000
#
#                   fano_sg  f1_f0_dg  g_dsi_dg  g_osi_dg  ...  \
# ecephys_unit_id                                          ...
# 951851547        4.540271  0.486314  0.055257  0.106719  ...
# 951851557        0.561962  0.219433  0.012115  0.031051  ...
# 951851661        3.728845  0.142864  0.027701  0.125591  ...
# 951851709        1.002197  0.174805  0.006659  0.020427  ...
# 951851731        0.782683  0.098212  0.021482  0.037944  ...
# ...                   ...       ...       ...       ...  ...
# 951879329        4.632228  0.974067  0.122637  0.155414  ...
# 951879341        1.377778  1.067739  0.066026  0.133947  ...
# 951879353        2.488836  0.550023  0.040292  0.080965  ...
# 951879365        1.714286  0.712458  0.014104  0.123829  ...
# 951879452        1.333333  1.195610  0.128929  0.085009  ...
#
#                  pref_ori_multi_dg  pref_ori_multi_sg  pref_phase_multi_sg  \
# ecephys_unit_id
# 951851547                    False              False                False
# 951851557                    False              False                False
# 951851661                    False              False                False
# 951851709                    False              False                False
# 951851731                    False              False                False
# ...                            ...                ...                  ...
# 951879329                    False              False                False
# 951879341                    False              False                False
# 951879353                    False              False                False
# 951879365                    False              False                False
# 951879452                    False              False                False
#
#                  image_selectivity_ns  pref_images_multi_ns  \
# ecephys_unit_id
# 951851547                   -0.006763                 False
# 951851557                    0.093966                 False
# 951851661                   -0.159983                 False
# 951851709                   -0.009729                 False
# 951851731                    0.409390                 False
# ...                               ...                   ...
# 951879329                    0.253220                 False
# 951879341                    0.297610                 False
# 951879353                    0.263746                 False
# 951879365                    0.017898                 False
# 951879452                    0.286119                 False
#
#                  lifetime_sparseness_dg  lifetime_sparseness_fl  \
# ecephys_unit_id
# 951851547                      0.111297                0.000007
# 951851557                      0.005364                0.009396
# 951851661                      0.041867                0.004052
# 951851709                      0.007285                0.005525
# 951851731                      0.011076                0.000954
# ...                                 ...                     ...
# 951879329                      0.082745                0.000000
# 951879341                      0.098976                0.000000
# 951879353                      0.044187                0.000769
# 951879365                      0.025563                0.050710
# 951879452                      0.425327                0.400000
#
#                  lifetime_sparseness_ns  lifetime_sparseness_rf  \
# ecephys_unit_id
# 951851547                      0.077239                0.295484
# 951851557                      0.002433                0.022345
# 951851661                      0.015362                0.055010
# 951851709                      0.007184                0.223867
# 951851731                      0.003655                0.004058
# ...                                 ...                     ...
# 951879329                      0.101565                0.926538
# 951879341                      0.072949                0.319633
# 951879353                      0.044551                0.589852
# 951879365                      0.025788                0.397572
# 951879452                      0.111731                0.654946
#
#                  lifetime_sparseness_sg
# ecephys_unit_id
# 951851547                      0.050071
# 951851557                      0.004122
# 951851661                      0.016025
# 951851709                      0.009256
# 951851731                      0.005345
# ...                                 ...
# 951879329                      0.092105
# 951879341                      0.073288
# 951879353                      0.046693
# 951879365                      0.030363
# 951879452                      0.092457
#
# [511 rows x 57 columns]

# %%
# Use normalized RF area for size mapping
functional_metrics_df['area_rf_normalized'] = (functional_metrics_df['area_rf'] - np.nanmin(functional_metrics_df['area_rf'])) / \
                            (np.nanmax(functional_metrics_df['area_rf']) - np.nanmin(functional_metrics_df['area_rf']))

# %%
# Color mapping from bioRxiv paper
color_dict = {'LGd':   [0.8509803921568627, 0.5529411764705883, 0.7607843137254902],
              'VISp':  [0.5058823529411764, 0.4549019607843137, 0.6941176470588235],
              'VISl':  [0.3058823529411765, 0.45098039215686275, 0.6823529411764706],
              'VISrl': [0.396078431372549, 0.6980392156862745, 0.788235294117647],
              'LP':    [0.34509803921568627, 0.6549019607843137, 0.41568627450980394],
              'VISal': [0.792156862745098, 0.7176470588235294, 0.47058823529411764],
              'VISpm': [0.8588235294117647, 0.5176470588235295, 0.3411764705882353],
              'VISam': [0.7607843137254902, 0.30980392156862746, 0.32941176470588235]}

# %%
units_locations = []
units_sizes = []
units_colors = []
for structure in structures:
    target_df = units_df[units_df.ecephys_structure_acronym == structure]
    
    units_locations.append(target_df[['anterior_posterior_ccf_coordinate',
                                      'dorsal_ventral_ccf_coordinate',
                                      'left_right_ccf_coordinate']].values)
    units_sizes.append(functional_metrics_df.loc[target_df.index, 'area_rf_normalized'].values)
    units_colors.append([color_dict[structure]]*len(target_df))

# %%
# First view the units each each structure as a set of markers
ccf = CCFWidget(markers=units_locations, marker_colors=[color_dict[s] for s in structures], selected_acronyms=structures)
ccf
# Out:
# CCFWidget(children=(VBox(children=(Viewer(background=(0.0, 0.0, 0.0), camera=array([[ 1.3441567e+03, -2.172384…

# %%
# Restore an interactively selected camera position
ccf.itk_viewer.camera = np.array([[ 1.0669220e+03, -2.7697236e+03,  2.2551131e+04],
       [ 8.0703340e+03,  3.2425415e+03,  6.0534639e+03],
       [-4.8250306e-02, -9.3169540e-01, -3.6002162e-01]], dtype=np.float32)

# %%
# To obtain the camera position
ccf.itk_viewer.camera
# Out:
# array([[ 1.0669220e+03, -2.7697236e+03,  2.2551131e+04],
#        [ 8.0703340e+03,  3.2425415e+03,  6.0534639e+03],
#        [-4.8250306e-02, -9.3169540e-01, -3.6002162e-01]], dtype=float32)

# %%
# View units for a subset of areas
areas = ['VISl', 'VISrl']

# Create mapping for areas
mapping = {k: i for i, k in enumerate(structures)}
idx = [mapping[a] for a in areas]

# Helper function to flatten list of lists
flatten = lambda l: [item for sublist in l for item in sublist]

# Update markers
markers = flatten([[u[None,:] for u in units_locations[i]] for i in idx])
# Rescale marker sizes to 1-10
marker_sizes = flatten([(units_sizes[i]*10+1).tolist() for i in idx])
marker_colors = flatten([units_colors[i] for i in idx])

ccf = CCFWidget(markers=markers, marker_sizes=marker_sizes, marker_colors=marker_colors, selected_acronyms=areas)
ccf
# Out:
# CCFWidget(children=(VBox(children=(Viewer(background=(0.0, 0.0, 0.0), camera=array([[ 1.3441567e+03, -2.172384…
